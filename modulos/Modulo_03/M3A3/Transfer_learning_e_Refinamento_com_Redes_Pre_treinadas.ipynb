# %% [markdown]
# # M3A3 - Transfer learning e Refinamento com Redes Pré-treinadas

# %% [markdown]
# Na prática de hoje vamos refinar modelos de aprendizado profundo com [PyTorch](https://pytorch.org/).
#
# Esse notebook está estruturado da seguinte forma.
#
# - Introdução
# - Carregar Base de Dados
# - Refinar Modelo
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Introdução

# %% [markdown]
# Instalação para os que ainda não possuem a biblioteca instalada.

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (2.11.0+cu128)
# Requirement already satisfied: torchvision in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (0.26.0+cu128)
# Requirement already satisfied: filelock in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (2026.6.0)
# Requirement already satisfied: numpy in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torchvision) (2.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from jinja2->torch) (3.0.3)

# %% [markdown]
# Importar as bibliotecas e Ler Imagens do Disco

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
import torchvision

# %% [markdown]
# ## Carregar Base de Dados
#
# A primeira tarefa para refinar um modelo é criar a base de dados.

# %%
# Definir o pré-processamento dos dados.
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                            torchvision.transforms.Resize(256),
                                            torchvision.transforms.CenterCrop(224)])

# Carregar o conjunto de treino.
train_data = torchvision.datasets.MNIST(
    root='./data',      # Pasta para salvar os dados.
    train=True,         # Busca pelo sub conjunto de treino.
    download=True,      # Download do dados se necessário.
    transform=transform # Transformação a ser aplicada.
)

# Carregar o conjunto de teste.
test_data = torchvision.datasets.MNIST(
    root='./data',      # Pasta para salvar os dados.
    train=False,        # Busca pelo sub conjunto de teste.
    download=True,      # Download do dados se necessário.
    transform=transform # Transformação a ser aplicada.
)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
# Visualizar duas imagens aleatórias da base de dados.
indexes = [np.random.randint(0, len(train_data)), np.random.randint(0, len(train_data))]

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 8))
axes[0].imshow(train_data[indexes[0]][0].numpy().transpose(1,2,0), cmap="gray")
axes[1].imshow(train_data[indexes[1]][0].numpy().transpose(1,2,0), cmap="gray")
plt.show()

# %% [markdown]
# ## Refinar Modelo
#
# Agora vamos carregar o modelo e refinar.

# %%
# Carregar o modelo
vgg_16_model = torchvision.models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1)

# Vamos alterar a última camada.
num_classes = 10  # Número de classes na nova base.
in_features = vgg_16_model.classifier[6].in_features # Features que chegam na última camada.
vgg_16_model.classifier[6] = torch.nn.Linear(in_features, num_classes) # Substiu a última camada.

# Vamos alterar a primeira camada da rede.
new_first_conv = torch.nn.Conv2d(1, 64, kernel_size=3, padding=1)
# Replace the original first layer
vgg_16_model.features[0] = new_first_conv

# %%
# Vamos colocar o modelo em modo de avaliação.
vgg_16_model.eval()

# Criar o dataloader para iterar nos dados.
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False, num_workers=1)

# Validar dispositivo de treino.
device = "cuda" if torch.cuda.is_available() else "cpu"

# Colocar modelo no dispositivo.
vgg_16_model.to(device)

# Vamos medir a performance do modelo sem o refinamento.
correct = 0
for batch_idx, (data, target) in enumerate(test_loader):
    # Coloando os dados nos dispositivos.
    data = data.to(device)
    target = target.to(device)

    # Processando os dados.
    output = vgg_16_model(data)
    if target == torch.argmax(torch.softmax(output, dim=1)):
        correct = correct + 1

# Calcula acurácia.
acc = correct/len(test_data)
print(f"Acurácia com modelo sem refinamento: {acc * 100}%")
# Out:
# Acurácia com modelo sem refinamento: 9.64%

# %%
########################
## Processo de treino. ##
########################

# Criando otimizador.
optimizer = torch.optim.SGD(vgg_16_model.parameters(), lr=0.0001)

# Definindo função de perda.
loss_criterion = torch.nn.CrossEntropyLoss()

# Criar o dataloader de treino.
batch_size = 16 # Define quantas instâncias serão processadas em uma passada do modelo.
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=4)

# Laço de treinamento.
epochs = 1
for epoch in range(epochs):
    # Colocar modelo em modo de treino.
    vgg_16_model.train()

    # Colocar modelo no dispositivo.
    vgg_16_model.to(device)
    
    # Função de perda e Acurácia para epóca.
    train_loss = 0.0
    train_acc = 0.0
    for batch_idx, (inputs, labels) in enumerate(train_loader):
        # Move os dados para o dispositivo de computação.
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Limpando os gradientes do otimizador.
        optimizer.zero_grad()

        # Passando informação no modelo.
        outputs = vgg_16_model(inputs)
        
        # Calculando a função de perda.
        loss = loss_criterion(outputs, labels)

        # Backpropagation dos gradientes.
        loss.backward()

        # Atualização dos parâmetros.
        optimizer.step()

        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
        
        # Calcule a acurácia.
        _, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
        
        # Calcular a acurácia do batch.
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
        
        # Calcular a acurácia total.
        train_acc += acc.item() * inputs.size(0)
        print("Batch number: {:03d}/{:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(batch_idx, len(train_data) // batch_size, loss.item(), acc.item()))
# Out:
# Batch number: 000/3750, Training: Loss: 2.3098, Accuracy: 0.1250
# Batch number: 001/3750, Training: Loss: 2.4263, Accuracy: 0.0625
# Batch number: 002/3750, Training: Loss: 2.2958, Accuracy: 0.0625
# Batch number: 003/3750, Training: Loss: 2.3403, Accuracy: 0.1250
# Batch number: 004/3750, Training: Loss: 2.3868, Accuracy: 0.0625
# Batch number: 005/3750, Training: Loss: 2.4394, Accuracy: 0.0000
# Batch number: 006/3750, Training: Loss: 2.3611, Accuracy: 0.1250
# Batch number: 007/3750, Training: Loss: 2.2917, Accuracy: 0.3125
# Batch number: 008/3750, Training: Loss: 2.3438, Accuracy: 0.0000
# Batch number: 009/3750, Training: Loss: 2.3298, Accuracy: 0.0000
# Batch number: 010/3750, Training: Loss: 2.2059, Accuracy: 0.3125
# Batch number: 011/3750, Training: Loss: 2.3775, Accuracy: 0.0625
# Batch number: 012/3750, Training: Loss: 2.2677, Accuracy: 0.1875
# Batch number: 013/3750, Training: Loss: 2.3060, Accuracy: 0.0000
# Batch number: 014/3750, Training: Loss: 2.2891, Accuracy: 0.0625
# Batch number: 015/3750, Training: Loss: 2.3947, Accuracy: 0.0000
# Batch number: 016/3750, Training: Loss: 2.3564, Accuracy: 0.0625
# Batch number: 017/3750, Training: Loss: 2.2630, Accuracy: 0.1875
# Batch number: 018/3750, Training: Loss: 2.2452, Accuracy: 0.1875
# Batch number: 019/3750, Training: Loss: 2.3877, Accuracy: 0.0000
# Batch number: 020/3750, Training: Loss: 2.3458, Accuracy: 0.0625
# Batch number: 021/3750, Training: Loss: 2.3796, Accuracy: 0.0625
# Batch number: 022/3750, Training: Loss: 2.3089, Accuracy: 0.0625
# Batch number: 023/3750, Training: Loss: 2.3367, Accuracy: 0.1250
# Batch number: 024/3750, Training: Loss: 2.3353, Accuracy: 0.0000
# Batch number: 025/3750, Training: Loss: 2.3250, Accuracy: 0.0625
# Batch number: 026/3750, Training: Loss: 2.2948, Accuracy: 0.0000
# Batch number: 027/3750, Training: Loss: 2.2677, Accuracy: 0.1875
# Batch number: 028/3750, Training: Loss: 2.2449, Accuracy: 0.1250
# Batch number: 029/3750, Training: Loss: 2.4286, Accuracy: 0.0625
# Batch number: 030/3750, Training: Loss: 2.3576, Accuracy: 0.0625
# Batch number: 031/3750, Training: Loss: 2.3545, Accuracy: 0.0625
# Batch number: 032/3750, Training: Loss: 2.3648, Accuracy: 0.0625
# Batch number: 033/3750, Training: Loss: 2.4800, Accuracy: 0.1250
# Batch number: 034/3750, Training: Loss: 2.3509, Accuracy: 0.1250
# Batch number: 035/3750, Training: Loss: 2.3796, Accuracy: 0.0000
# Batch number: 036/3750, Training: Loss: 2.3492, Accuracy: 0.1875
# Batch number: 037/3750, Training: Loss: 2.3221, Accuracy: 0.1875
# Batch number: 038/3750, Training: Loss: 2.3203, Accuracy: 0.1250
# Batch number: 039/3750, Training: Loss: 2.3379, Accuracy: 0.0625
# Batch number: 040/3750, Training: Loss: 2.3404, Accuracy: 0.0625
# Batch number: 041/3750, Training: Loss: 2.2691, Accuracy: 0.0625
# Batch number: 042/3750, Training: Loss: 2.4019, Accuracy: 0.0000
# Batch number: 043/3750, Training: Loss: 2.2701, Accuracy: 0.1250
# Batch number: 044/3750, Training: Loss: 2.3143, Accuracy: 0.0625
# Batch number: 045/3750, Training: Loss: 2.3704, Accuracy: 0.1250
# Batch number: 046/3750, Training: Loss: 2.3796, Accuracy: 0.0625
# Batch number: 047/3750, Training: Loss: 2.3723, Accuracy: 0.0000
# Batch number: 048/3750, Training: Loss: 2.2649, Accuracy: 0.0625
# Batch number: 049/3750, Training: Loss: 2.4215, Accuracy: 0.0000
# Batch number: 050/3750, Training: Loss: 2.1830, Accuracy: 0.3125
# Batch number: 051/3750, Training: Loss: 2.3261, Accuracy: 0.0625
# Batch number: 052/3750, Training: Loss: 2.1909, Accuracy: 0.3750
# Batch number: 053/3750, Training: Loss: 2.3005, Accuracy: 0.1250
# Batch number: 054/3750, Training: Loss: 2.3613, Accuracy: 0.0000
# Batch number: 055/3750, Training: Loss: 2.3037, Accuracy: 0.1250
# Batch number: 056/3750, Training: Loss: 2.3629, Accuracy: 0.0625
# Batch number: 057/3750, Training: Loss: 2.3892, Accuracy: 0.0625
# Batch number: 058/3750, Training: Loss: 2.2476, Accuracy: 0.1875
# Batch number: 059/3750, Training: Loss: 2.3696, Accuracy: 0.0625
# Batch number: 060/3750, Training: Loss: 2.3419, Accuracy: 0.0000
# Batch number: 061/3750, Training: Loss: 2.3273, Accuracy: 0.0625
# Batch number: 062/3750, Training: Loss: 2.3472, Accuracy: 0.0625
# Batch number: 063/3750, Training: Loss: 2.4020, Accuracy: 0.0625
# Batch number: 064/3750, Training: Loss: 2.2602, Accuracy: 0.2500
# Batch number: 065/3750, Training: Loss: 2.2868, Accuracy: 0.1875
# Batch number: 066/3750, Training: Loss: 2.3459, Accuracy: 0.1875
# Batch number: 067/3750, Training: Loss: 2.2588, Accuracy: 0.0625
# Batch number: 068/3750, Training: Loss: 2.4022, Accuracy: 0.0625
# Batch number: 069/3750, Training: Loss: 2.3037, Accuracy: 0.1875
# Batch number: 070/3750, Training: Loss: 2.2702, Accuracy: 0.0625
# Batch number: 071/3750, Training: Loss: 2.3146, Accuracy: 0.0625
# Batch number: 072/3750, Training: Loss: 2.3974, Accuracy: 0.0625
# Batch number: 073/3750, Training: Loss: 2.2593, Accuracy: 0.1875
# Batch number: 074/3750, Training: Loss: 2.3328, Accuracy: 0.2500
# Batch number: 075/3750, Training: Loss: 2.3049, Accuracy: 0.1250
# Batch number: 076/3750, Training: Loss: 2.2844, Accuracy: 0.1250
# Batch number: 077/3750, Training: Loss: 2.2981, Accuracy: 0.1875
# Batch number: 078/3750, Training: Loss: 2.3202, Accuracy: 0.1250
# Batch number: 079/3750, Training: Loss: 2.3173, Accuracy: 0.1875
# Batch number: 080/3750, Training: Loss: 2.3219, Accuracy: 0.0625
# Batch number: 081/3750, Training: Loss: 2.2899, Accuracy: 0.1250
# Batch number: 082/3750, Training: Loss: 2.3020, Accuracy: 0.1250
# Batch number: 083/3750, Training: Loss: 2.3539, Accuracy: 0.0000
# Batch number: 084/3750, Training: Loss: 2.2617, Accuracy: 0.1250
# Batch number: 085/3750, Training: Loss: 2.2563, Accuracy: 0.0625
# Batch number: 086/3750, Training: Loss: 2.3365, Accuracy: 0.0000
# Batch number: 169/3750, Training: Loss: 2.3159, Accuracy: 0.0625
# Batch number: 170/3750, Training: Loss: 2.3211, Accuracy: 0.1250
# Batch number: 171/3750, Training: Loss: 2.1905, Accuracy: 0.0625
# Batch number: 172/3750, Training: Loss: 2.2840, Accuracy: 0.1250
# Batch number: 173/3750, Training: Loss: 2.2472, Accuracy: 0.3125
# Batch number: 174/3750, Training: Loss: 2.3497, Accuracy: 0.0625
# Batch number: 175/3750, Training: Loss: 2.2891, Accuracy: 0.1250
# Batch number: 176/3750, Training: Loss: 2.2515, Accuracy: 0.0625
# Batch number: 177/3750, Training: Loss: 2.3174, Accuracy: 0.1875
# Batch number: 178/3750, Training: Loss: 2.3571, Accuracy: 0.1250
# Batch number: 179/3750, Training: Loss: 2.2977, Accuracy: 0.0625
# Batch number: 180/3750, Training: Loss: 2.2985, Accuracy: 0.1250
# Batch number: 181/3750, Training: Loss: 2.3056, Accuracy: 0.1875
# Batch number: 182/3750, Training: Loss: 2.2787, Accuracy: 0.1875
# Batch number: 183/3750, Training: Loss: 2.3347, Accuracy: 0.0625
# Batch number: 184/3750, Training: Loss: 2.2514, Accuracy: 0.0000
# Batch number: 185/3750, Training: Loss: 2.2327, Accuracy: 0.2500
# Batch number: 186/3750, Training: Loss: 2.2788, Accuracy: 0.1250
# Batch number: 187/3750, Training: Loss: 2.3918, Accuracy: 0.0000
# Batch number: 188/3750, Training: Loss: 2.2442, Accuracy: 0.2500
# Batch number: 189/3750, Training: Loss: 2.2645, Accuracy: 0.1250
# Batch number: 190/3750, Training: Loss: 2.2869, Accuracy: 0.0000
# Batch number: 191/3750, Training: Loss: 2.1913, Accuracy: 0.2500
# Batch number: 192/3750, Training: Loss: 2.3311, Accuracy: 0.0625
# Batch number: 193/3750, Training: Loss: 2.2198, Accuracy: 0.1250
# Batch number: 194/3750, Training: Loss: 2.2024, Accuracy: 0.2500
# Batch number: 195/3750, Training: Loss: 2.2383, Accuracy: 0.1250
# Batch number: 196/3750, Training: Loss: 2.2546, Accuracy: 0.1250
# Batch number: 197/3750, Training: Loss: 2.3006, Accuracy: 0.0000
# Batch number: 198/3750, Training: Loss: 2.3106, Accuracy: 0.0000
# Batch number: 199/3750, Training: Loss: 2.2725, Accuracy: 0.1250
# Batch number: 200/3750, Training: Loss: 2.2185, Accuracy: 0.3750
# Batch number: 201/3750, Training: Loss: 2.2651, Accuracy: 0.1250
# Batch number: 202/3750, Training: Loss: 2.2457, Accuracy: 0.1250
# Batch number: 203/3750, Training: Loss: 2.3752, Accuracy: 0.0625
# Batch number: 204/3750, Training: Loss: 2.3186, Accuracy: 0.0625
# Batch number: 205/3750, Training: Loss: 2.2725, Accuracy: 0.1250
# Batch number: 206/3750, Training: Loss: 2.2331, Accuracy: 0.1250
# Batch number: 207/3750, Training: Loss: 2.3337, Accuracy: 0.0625
# Batch number: 208/3750, Training: Loss: 2.3320, Accuracy: 0.0000
# Batch number: 209/3750, Training: Loss: 2.2498, Accuracy: 0.1250
# Batch number: 251/3750, Training: Loss: 2.2560, Accuracy: 0.1250
# Batch number: 252/3750, Training: Loss: 2.2230, Accuracy: 0.1250
# Batch number: 253/3750, Training: Loss: 2.2533, Accuracy: 0.1875
# Batch number: 254/3750, Training: Loss: 2.2925, Accuracy: 0.1250
# Batch number: 255/3750, Training: Loss: 2.2444, Accuracy: 0.1250
# Batch number: 256/3750, Training: Loss: 2.3041, Accuracy: 0.0625
# Batch number: 257/3750, Training: Loss: 2.2261, Accuracy: 0.3125
# Batch number: 258/3750, Training: Loss: 2.1919, Accuracy: 0.3125
# Batch number: 259/3750, Training: Loss: 2.2214, Accuracy: 0.2500
# Batch number: 260/3750, Training: Loss: 2.2144, Accuracy: 0.0625
# Batch number: 261/3750, Training: Loss: 2.2686, Accuracy: 0.1875
# Batch number: 262/3750, Training: Loss: 2.3457, Accuracy: 0.0625
# Batch number: 263/3750, Training: Loss: 2.4090, Accuracy: 0.0000
# Batch number: 264/3750, Training: Loss: 2.3139, Accuracy: 0.1875
# Batch number: 265/3750, Training: Loss: 2.2017, Accuracy: 0.2500
# Batch number: 266/3750, Training: Loss: 2.2300, Accuracy: 0.1875
# Batch number: 267/3750, Training: Loss: 2.2901, Accuracy: 0.0625
# Batch number: 268/3750, Training: Loss: 2.2078, Accuracy: 0.1875
# Batch number: 269/3750, Training: Loss: 2.3076, Accuracy: 0.0625
# Batch number: 270/3750, Training: Loss: 2.1540, Accuracy: 0.1875
# Batch number: 271/3750, Training: Loss: 2.1782, Accuracy: 0.2500
# Batch number: 272/3750, Training: Loss: 2.2982, Accuracy: 0.0625
# Batch number: 273/3750, Training: Loss: 2.2838, Accuracy: 0.0625
# Batch number: 274/3750, Training: Loss: 2.2443, Accuracy: 0.1250
# Batch number: 275/3750, Training: Loss: 2.3327, Accuracy: 0.0000
# Batch number: 276/3750, Training: Loss: 2.3440, Accuracy: 0.0625
# Batch number: 277/3750, Training: Loss: 2.3013, Accuracy: 0.0000
# Batch number: 278/3750, Training: Loss: 2.3072, Accuracy: 0.1250
# Batch number: 279/3750, Training: Loss: 2.2853, Accuracy: 0.2500
# Batch number: 280/3750, Training: Loss: 2.2301, Accuracy: 0.0625
# Batch number: 281/3750, Training: Loss: 2.1658, Accuracy: 0.2500
# Batch number: 282/3750, Training: Loss: 2.2283, Accuracy: 0.1250
# Batch number: 283/3750, Training: Loss: 2.2133, Accuracy: 0.2500
# Batch number: 284/3750, Training: Loss: 2.2994, Accuracy: 0.0625
# Batch number: 285/3750, Training: Loss: 2.2757, Accuracy: 0.0625
# Batch number: 286/3750, Training: Loss: 2.2689, Accuracy: 0.1250
# Batch number: 287/3750, Training: Loss: 2.3038, Accuracy: 0.1250
# Batch number: 288/3750, Training: Loss: 2.3294, Accuracy: 0.0625
# Batch number: 289/3750, Training: Loss: 2.2694, Accuracy: 0.1250
# Batch number: 290/3750, Training: Loss: 2.3356, Accuracy: 0.0000
# Batch number: 291/3750, Training: Loss: 2.2005, Accuracy: 0.1875
# Batch number: 292/3750, Training: Loss: 2.2974, Accuracy: 0.2500
# Batch number: 498/3750, Training: Loss: 2.2355, Accuracy: 0.1250
# Batch number: 499/3750, Training: Loss: 2.2575, Accuracy: 0.1250
# Batch number: 500/3750, Training: Loss: 2.2047, Accuracy: 0.1875
# Batch number: 501/3750, Training: Loss: 2.1936, Accuracy: 0.3125
# Batch number: 502/3750, Training: Loss: 2.2185, Accuracy: 0.1250
# Batch number: 503/3750, Training: Loss: 2.2374, Accuracy: 0.1250
# Batch number: 504/3750, Training: Loss: 2.3050, Accuracy: 0.0625
# Batch number: 505/3750, Training: Loss: 2.2114, Accuracy: 0.3125
# Batch number: 506/3750, Training: Loss: 2.2794, Accuracy: 0.1875
# Batch number: 507/3750, Training: Loss: 2.1539, Accuracy: 0.1875
# Batch number: 508/3750, Training: Loss: 2.1908, Accuracy: 0.3750
# Batch number: 509/3750, Training: Loss: 2.1559, Accuracy: 0.3125
# Batch number: 510/3750, Training: Loss: 2.2394, Accuracy: 0.2500
# Batch number: 511/3750, Training: Loss: 2.2679, Accuracy: 0.2500
# Batch number: 512/3750, Training: Loss: 2.1825, Accuracy: 0.2500
# Batch number: 513/3750, Training: Loss: 2.3513, Accuracy: 0.0000
# Batch number: 514/3750, Training: Loss: 2.2270, Accuracy: 0.1875
# Batch number: 515/3750, Training: Loss: 2.1780, Accuracy: 0.1875
# Batch number: 516/3750, Training: Loss: 2.2513, Accuracy: 0.1875
# Batch number: 517/3750, Training: Loss: 2.2415, Accuracy: 0.1250
# Batch number: 518/3750, Training: Loss: 2.1875, Accuracy: 0.1875
# Batch number: 519/3750, Training: Loss: 2.2335, Accuracy: 0.1875
# Batch number: 520/3750, Training: Loss: 2.2401, Accuracy: 0.1875
# Batch number: 521/3750, Training: Loss: 2.2189, Accuracy: 0.1250
# Batch number: 522/3750, Training: Loss: 2.2549, Accuracy: 0.0625
# Batch number: 523/3750, Training: Loss: 2.2063, Accuracy: 0.1875
# Batch number: 524/3750, Training: Loss: 2.2382, Accuracy: 0.1875
# Batch number: 525/3750, Training: Loss: 2.2191, Accuracy: 0.2500
# Batch number: 526/3750, Training: Loss: 2.2331, Accuracy: 0.1875
# Batch number: 527/3750, Training: Loss: 2.2718, Accuracy: 0.1875
# Batch number: 528/3750, Training: Loss: 2.2335, Accuracy: 0.1875
# Batch number: 529/3750, Training: Loss: 2.2133, Accuracy: 0.0625
# Batch number: 530/3750, Training: Loss: 2.1705, Accuracy: 0.2500
# Batch number: 531/3750, Training: Loss: 2.1793, Accuracy: 0.3125
# Batch number: 532/3750, Training: Loss: 2.3076, Accuracy: 0.0625
# Batch number: 533/3750, Training: Loss: 2.1607, Accuracy: 0.2500
# Batch number: 534/3750, Training: Loss: 2.2383, Accuracy: 0.1250
# Batch number: 535/3750, Training: Loss: 2.2151, Accuracy: 0.1875
# Batch number: 536/3750, Training: Loss: 2.1854, Accuracy: 0.3750
# Batch number: 537/3750, Training: Loss: 2.2201, Accuracy: 0.1250
# Batch number: 538/3750, Training: Loss: 2.2147, Accuracy: 0.2500
# Batch number: 580/3750, Training: Loss: 2.1570, Accuracy: 0.1875
# Batch number: 581/3750, Training: Loss: 2.1731, Accuracy: 0.3125
# Batch number: 582/3750, Training: Loss: 2.2377, Accuracy: 0.0625
# Batch number: 583/3750, Training: Loss: 2.3031, Accuracy: 0.1250
# Batch number: 584/3750, Training: Loss: 2.1447, Accuracy: 0.3125
# Batch number: 585/3750, Training: Loss: 2.3144, Accuracy: 0.0625
# Batch number: 586/3750, Training: Loss: 2.1187, Accuracy: 0.3750
# Batch number: 587/3750, Training: Loss: 2.2650, Accuracy: 0.1250
# Batch number: 588/3750, Training: Loss: 2.1809, Accuracy: 0.1250
# Batch number: 589/3750, Training: Loss: 2.2305, Accuracy: 0.2500
# Batch number: 590/3750, Training: Loss: 2.1932, Accuracy: 0.1875
# Batch number: 591/3750, Training: Loss: 2.1455, Accuracy: 0.2500
# Batch number: 592/3750, Training: Loss: 2.2916, Accuracy: 0.0000
# Batch number: 593/3750, Training: Loss: 2.1957, Accuracy: 0.1250
# Batch number: 594/3750, Training: Loss: 2.1921, Accuracy: 0.1250
# Batch number: 595/3750, Training: Loss: 2.2272, Accuracy: 0.2500
# Batch number: 596/3750, Training: Loss: 2.1632, Accuracy: 0.3125
# Batch number: 597/3750, Training: Loss: 2.2303, Accuracy: 0.1250
# Batch number: 598/3750, Training: Loss: 2.1403, Accuracy: 0.4375
# Batch number: 599/3750, Training: Loss: 2.2077, Accuracy: 0.3125
# Batch number: 600/3750, Training: Loss: 2.2509, Accuracy: 0.1250
# Batch number: 601/3750, Training: Loss: 2.1538, Accuracy: 0.3125
# Batch number: 602/3750, Training: Loss: 2.1562, Accuracy: 0.1875
# Batch number: 603/3750, Training: Loss: 2.1644, Accuracy: 0.3750
# Batch number: 604/3750, Training: Loss: 2.1624, Accuracy: 0.2500
# Batch number: 605/3750, Training: Loss: 2.2282, Accuracy: 0.1875
# Batch number: 606/3750, Training: Loss: 2.2896, Accuracy: 0.2500
# Batch number: 607/3750, Training: Loss: 2.2918, Accuracy: 0.0625
# Batch number: 608/3750, Training: Loss: 2.1606, Accuracy: 0.3750
# Batch number: 609/3750, Training: Loss: 2.2375, Accuracy: 0.1250
# Batch number: 610/3750, Training: Loss: 2.1936, Accuracy: 0.2500
# Batch number: 611/3750, Training: Loss: 2.2330, Accuracy: 0.1250
# Batch number: 612/3750, Training: Loss: 2.1657, Accuracy: 0.3125
# Batch number: 613/3750, Training: Loss: 2.2197, Accuracy: 0.1250
# Batch number: 614/3750, Training: Loss: 2.1206, Accuracy: 0.2500
# Batch number: 615/3750, Training: Loss: 2.1975, Accuracy: 0.1250
# Batch number: 616/3750, Training: Loss: 2.2423, Accuracy: 0.1250
# Batch number: 617/3750, Training: Loss: 2.2229, Accuracy: 0.2500
# Batch number: 618/3750, Training: Loss: 2.1848, Accuracy: 0.2500
# Batch number: 619/3750, Training: Loss: 2.0758, Accuracy: 0.2500
# Batch number: 620/3750, Training: Loss: 2.2799, Accuracy: 0.1875
# Batch number: 621/3750, Training: Loss: 2.2432, Accuracy: 0.0625
# Batch number: 622/3750, Training: Loss: 2.1611, Accuracy: 0.3125
# Batch number: 623/3750, Training: Loss: 2.2386, Accuracy: 0.1875
# Batch number: 624/3750, Training: Loss: 2.1704, Accuracy: 0.3125
# Batch number: 625/3750, Training: Loss: 2.2824, Accuracy: 0.0625
# Batch number: 626/3750, Training: Loss: 2.1547, Accuracy: 0.4375
# Batch number: 627/3750, Training: Loss: 2.1771, Accuracy: 0.3125
# Batch number: 628/3750, Training: Loss: 2.2202, Accuracy: 0.2500
# Batch number: 629/3750, Training: Loss: 2.1623, Accuracy: 0.3750
# Batch number: 630/3750, Training: Loss: 2.2161, Accuracy: 0.1875
# Batch number: 631/3750, Training: Loss: 2.1474, Accuracy: 0.3750
# Batch number: 632/3750, Training: Loss: 2.1633, Accuracy: 0.3125
# Batch number: 633/3750, Training: Loss: 2.2139, Accuracy: 0.1250
# Batch number: 634/3750, Training: Loss: 2.1535, Accuracy: 0.1875
# Batch number: 635/3750, Training: Loss: 2.1821, Accuracy: 0.1875
# Batch number: 636/3750, Training: Loss: 2.1228, Accuracy: 0.4375
# Batch number: 637/3750, Training: Loss: 2.0896, Accuracy: 0.3125
# Batch number: 638/3750, Training: Loss: 2.2583, Accuracy: 0.1875
# Batch number: 639/3750, Training: Loss: 2.2378, Accuracy: 0.1250
# Batch number: 640/3750, Training: Loss: 2.1732, Accuracy: 0.2500
# Batch number: 641/3750, Training: Loss: 2.2100, Accuracy: 0.0625
# Batch number: 642/3750, Training: Loss: 2.0336, Accuracy: 0.5000
# Batch number: 643/3750, Training: Loss: 2.1097, Accuracy: 0.1875
# Batch number: 644/3750, Training: Loss: 2.1877, Accuracy: 0.1875
# Batch number: 645/3750, Training: Loss: 2.1096, Accuracy: 0.2500
# Batch number: 646/3750, Training: Loss: 2.1995, Accuracy: 0.1250
# Batch number: 647/3750, Training: Loss: 2.2327, Accuracy: 0.0000
# Batch number: 648/3750, Training: Loss: 2.1330, Accuracy: 0.3125
# Batch number: 649/3750, Training: Loss: 2.1613, Accuracy: 0.1875
# Batch number: 650/3750, Training: Loss: 2.1838, Accuracy: 0.2500
# Batch number: 651/3750, Training: Loss: 2.2380, Accuracy: 0.2500
# Batch number: 652/3750, Training: Loss: 2.2021, Accuracy: 0.1875
# Batch number: 653/3750, Training: Loss: 2.2981, Accuracy: 0.0625
# Batch number: 654/3750, Training: Loss: 2.1970, Accuracy: 0.1875
# Batch number: 655/3750, Training: Loss: 2.2024, Accuracy: 0.0625
# Batch number: 656/3750, Training: Loss: 2.1944, Accuracy: 0.2500
# Batch number: 657/3750, Training: Loss: 2.1513, Accuracy: 0.1875
# Batch number: 658/3750, Training: Loss: 2.2740, Accuracy: 0.1250
# Batch number: 659/3750, Training: Loss: 2.2305, Accuracy: 0.1875
# Batch number: 660/3750, Training: Loss: 2.1581, Accuracy: 0.1250
# Batch number: 661/3750, Training: Loss: 2.1318, Accuracy: 0.3750
# Batch number: 662/3750, Training: Loss: 2.1711, Accuracy: 0.3125
# Batch number: 663/3750, Training: Loss: 2.1966, Accuracy: 0.2500
# Batch number: 664/3750, Training: Loss: 2.1601, Accuracy: 0.1875
# Batch number: 665/3750, Training: Loss: 2.2383, Accuracy: 0.0625
# Batch number: 666/3750, Training: Loss: 2.1529, Accuracy: 0.3125
# Batch number: 667/3750, Training: Loss: 2.1243, Accuracy: 0.3125
# Batch number: 668/3750, Training: Loss: 2.1335, Accuracy: 0.3125
# Batch number: 669/3750, Training: Loss: 2.1854, Accuracy: 0.2500
# Batch number: 670/3750, Training: Loss: 2.1779, Accuracy: 0.1250
# Batch number: 671/3750, Training: Loss: 2.0827, Accuracy: 0.3750
# Batch number: 672/3750, Training: Loss: 2.1236, Accuracy: 0.3750
# Batch number: 673/3750, Training: Loss: 2.1106, Accuracy: 0.2500
# Batch number: 674/3750, Training: Loss: 2.1635, Accuracy: 0.3750
# Batch number: 675/3750, Training: Loss: 2.2738, Accuracy: 0.0625
# Batch number: 676/3750, Training: Loss: 2.1059, Accuracy: 0.1875
# Batch number: 677/3750, Training: Loss: 2.1453, Accuracy: 0.2500
# Batch number: 678/3750, Training: Loss: 2.0983, Accuracy: 0.3750
# Batch number: 679/3750, Training: Loss: 2.1158, Accuracy: 0.1875
# Batch number: 680/3750, Training: Loss: 2.1570, Accuracy: 0.1875
# Batch number: 681/3750, Training: Loss: 2.1176, Accuracy: 0.1875
# Batch number: 682/3750, Training: Loss: 2.1903, Accuracy: 0.2500
# Batch number: 683/3750, Training: Loss: 2.2967, Accuracy: 0.0000
# Batch number: 684/3750, Training: Loss: 2.0667, Accuracy: 0.2500
# Batch number: 685/3750, Training: Loss: 2.1047, Accuracy: 0.5000
# Batch number: 686/3750, Training: Loss: 2.0742, Accuracy: 0.3750
# Batch number: 687/3750, Training: Loss: 2.0741, Accuracy: 0.4375
# Batch number: 688/3750, Training: Loss: 2.2327, Accuracy: 0.0625
# Batch number: 689/3750, Training: Loss: 2.1800, Accuracy: 0.1875
# Batch number: 690/3750, Training: Loss: 2.2235, Accuracy: 0.1875
# Batch number: 691/3750, Training: Loss: 2.0935, Accuracy: 0.2500
# Batch number: 692/3750, Training: Loss: 2.1673, Accuracy: 0.1875
# Batch number: 693/3750, Training: Loss: 2.1436, Accuracy: 0.1875
# Batch number: 694/3750, Training: Loss: 2.1637, Accuracy: 0.0625
# Batch number: 695/3750, Training: Loss: 2.1809, Accuracy: 0.1875
# Batch number: 696/3750, Training: Loss: 2.2109, Accuracy: 0.2500
# Batch number: 697/3750, Training: Loss: 2.2420, Accuracy: 0.1250
# Batch number: 698/3750, Training: Loss: 2.2371, Accuracy: 0.0625
# Batch number: 699/3750, Training: Loss: 2.1937, Accuracy: 0.1875
# Batch number: 700/3750, Training: Loss: 2.2916, Accuracy: 0.0625
# Batch number: 701/3750, Training: Loss: 2.1782, Accuracy: 0.1250
# Batch number: 702/3750, Training: Loss: 2.1224, Accuracy: 0.3125
# Batch number: 703/3750, Training: Loss: 2.1552, Accuracy: 0.3750
# Batch number: 704/3750, Training: Loss: 2.1705, Accuracy: 0.1875
# Batch number: 705/3750, Training: Loss: 2.2035, Accuracy: 0.2500
# Batch number: 706/3750, Training: Loss: 2.0778, Accuracy: 0.5000
# Batch number: 707/3750, Training: Loss: 2.1435, Accuracy: 0.2500
# Batch number: 708/3750, Training: Loss: 2.1742, Accuracy: 0.2500
# Batch number: 709/3750, Training: Loss: 2.2586, Accuracy: 0.1875
# Batch number: 710/3750, Training: Loss: 2.1686, Accuracy: 0.1875
# Batch number: 711/3750, Training: Loss: 2.1019, Accuracy: 0.3750
# Batch number: 712/3750, Training: Loss: 2.1492, Accuracy: 0.1875
# Batch number: 713/3750, Training: Loss: 2.1807, Accuracy: 0.1875
# Batch number: 714/3750, Training: Loss: 2.2165, Accuracy: 0.0625
# Batch number: 715/3750, Training: Loss: 2.2587, Accuracy: 0.1875
# Batch number: 716/3750, Training: Loss: 2.2114, Accuracy: 0.1875
# Batch number: 717/3750, Training: Loss: 2.1345, Accuracy: 0.3750
# Batch number: 718/3750, Training: Loss: 2.1838, Accuracy: 0.1875
# Batch number: 719/3750, Training: Loss: 2.1120, Accuracy: 0.2500
# Batch number: 720/3750, Training: Loss: 2.1484, Accuracy: 0.3125
# Batch number: 721/3750, Training: Loss: 2.1900, Accuracy: 0.1875
# Batch number: 722/3750, Training: Loss: 2.1281, Accuracy: 0.3750
# Batch number: 723/3750, Training: Loss: 2.1821, Accuracy: 0.2500
# Batch number: 724/3750, Training: Loss: 2.1706, Accuracy: 0.3750
# Batch number: 725/3750, Training: Loss: 2.1040, Accuracy: 0.2500
# Batch number: 726/3750, Training: Loss: 2.1624, Accuracy: 0.3125
# Batch number: 727/3750, Training: Loss: 2.2505, Accuracy: 0.1250
# Batch number: 728/3750, Training: Loss: 2.2202, Accuracy: 0.0625
# Batch number: 729/3750, Training: Loss: 2.1672, Accuracy: 0.1875
# Batch number: 730/3750, Training: Loss: 2.1024, Accuracy: 0.2500
# Batch number: 731/3750, Training: Loss: 2.1825, Accuracy: 0.0625
# Batch number: 732/3750, Training: Loss: 2.0876, Accuracy: 0.3750
# Batch number: 733/3750, Training: Loss: 2.1600, Accuracy: 0.1875
# Batch number: 734/3750, Training: Loss: 2.1330, Accuracy: 0.4375
# Batch number: 735/3750, Training: Loss: 2.2718, Accuracy: 0.1250
# Batch number: 736/3750, Training: Loss: 2.1044, Accuracy: 0.3750
# Batch number: 737/3750, Training: Loss: 2.1615, Accuracy: 0.3125
# ...
# Batch number: 3508/3750, Training: Loss: 0.3159, Accuracy: 0.8750
# Batch number: 3509/3750, Training: Loss: 0.3469, Accuracy: 0.8750
# Batch number: 3510/3750, Training: Loss: 0.1012, Accuracy: 1.0000
# Batch number: 3511/3750, Training: Loss: 0.2138, Accuracy: 0.9375
# Batch number: 3512/3750, Training: Loss: 0.4499, Accuracy: 0.9375
# Batch number: 3513/3750, Training: Loss: 0.4490, Accuracy: 0.8750
# Batch number: 3514/3750, Training: Loss: 0.2231, Accuracy: 0.9375
# Batch number: 3595/3750, Training: Loss: 0.1251, Accuracy: 1.0000
# Batch number: 3596/3750, Training: Loss: 0.0545, Accuracy: 1.0000
# Batch number: 3597/3750, Training: Loss: 0.5586, Accuracy: 0.8125
# Batch number: 3598/3750, Training: Loss: 0.1259, Accuracy: 1.0000
# Batch number: 3599/3750, Training: Loss: 0.2454, Accuracy: 0.8750
# Batch number: 3600/3750, Training: Loss: 0.3312, Accuracy: 0.9375
# Batch number: 3601/3750, Training: Loss: 0.2637, Accuracy: 0.8750
# Batch number: 3602/3750, Training: Loss: 0.4792, Accuracy: 0.8750
# Batch number: 3603/3750, Training: Loss: 0.3110, Accuracy: 0.8750
# Batch number: 3604/3750, Training: Loss: 0.4204, Accuracy: 0.8750
# Batch number: 3605/3750, Training: Loss: 0.1451, Accuracy: 0.9375
# Batch number: 3606/3750, Training: Loss: 0.2050, Accuracy: 0.9375
# Batch number: 3607/3750, Training: Loss: 0.3113, Accuracy: 0.9375
# Batch number: 3608/3750, Training: Loss: 0.1507, Accuracy: 1.0000
# Batch number: 3609/3750, Training: Loss: 0.0718, Accuracy: 1.0000
# Batch number: 3610/3750, Training: Loss: 0.2529, Accuracy: 0.8750
# Batch number: 3611/3750, Training: Loss: 0.3309, Accuracy: 0.8750
# Batch number: 3612/3750, Training: Loss: 0.1702, Accuracy: 0.9375
# Batch number: 3613/3750, Training: Loss: 0.1283, Accuracy: 1.0000
# Batch number: 3614/3750, Training: Loss: 0.2363, Accuracy: 0.8750
# Batch number: 3615/3750, Training: Loss: 0.2866, Accuracy: 0.8750
# Batch number: 3616/3750, Training: Loss: 0.1244, Accuracy: 1.0000
# Batch number: 3617/3750, Training: Loss: 0.1789, Accuracy: 0.9375
# Batch number: 3618/3750, Training: Loss: 0.2788, Accuracy: 0.8750
# Batch number: 3619/3750, Training: Loss: 0.0413, Accuracy: 1.0000
# Batch number: 3620/3750, Training: Loss: 0.7538, Accuracy: 0.8750
# Batch number: 3621/3750, Training: Loss: 0.2151, Accuracy: 0.9375
# Batch number: 3622/3750, Training: Loss: 0.2032, Accuracy: 0.9375
# Batch number: 3623/3750, Training: Loss: 0.3695, Accuracy: 0.8750
# Batch number: 3624/3750, Training: Loss: 0.2683, Accuracy: 0.8750
# Batch number: 3625/3750, Training: Loss: 0.1155, Accuracy: 0.9375
# Batch number: 3626/3750, Training: Loss: 0.0419, Accuracy: 1.0000
# Batch number: 3627/3750, Training: Loss: 0.1879, Accuracy: 0.9375
# Batch number: 3628/3750, Training: Loss: 0.0532, Accuracy: 1.0000
# Batch number: 3629/3750, Training: Loss: 0.0795, Accuracy: 1.0000
# Batch number: 3630/3750, Training: Loss: 0.3283, Accuracy: 0.8750
# Batch number: 3631/3750, Training: Loss: 0.1572, Accuracy: 1.0000
# Batch number: 3632/3750, Training: Loss: 0.3089, Accuracy: 0.8750
# Batch number: 3633/3750, Training: Loss: 0.1452, Accuracy: 0.9375
# Batch number: 3634/3750, Training: Loss: 0.2984, Accuracy: 0.8750
# Batch number: 3675/3750, Training: Loss: 0.8013, Accuracy: 0.6875
# Batch number: 3676/3750, Training: Loss: 0.3332, Accuracy: 0.8125
# Batch number: 3677/3750, Training: Loss: 0.1994, Accuracy: 0.9375
# Batch number: 3678/3750, Training: Loss: 0.0552, Accuracy: 1.0000
# Batch number: 3679/3750, Training: Loss: 0.1987, Accuracy: 0.9375
# Batch number: 3680/3750, Training: Loss: 0.2594, Accuracy: 0.8750
# Batch number: 3681/3750, Training: Loss: 0.1949, Accuracy: 1.0000
# Batch number: 3682/3750, Training: Loss: 0.2741, Accuracy: 0.8750
# Batch number: 3683/3750, Training: Loss: 0.1992, Accuracy: 0.8750
# Batch number: 3684/3750, Training: Loss: 0.1626, Accuracy: 0.9375
# Batch number: 3685/3750, Training: Loss: 0.0963, Accuracy: 1.0000
# Batch number: 3686/3750, Training: Loss: 0.2979, Accuracy: 0.8750
# Batch number: 3687/3750, Training: Loss: 0.1352, Accuracy: 0.9375
# Batch number: 3688/3750, Training: Loss: 0.2954, Accuracy: 0.9375
# Batch number: 3689/3750, Training: Loss: 0.2971, Accuracy: 0.9375
# Batch number: 3690/3750, Training: Loss: 0.5520, Accuracy: 0.8125
# Batch number: 3691/3750, Training: Loss: 0.2731, Accuracy: 0.9375
# Batch number: 3692/3750, Training: Loss: 0.3604, Accuracy: 0.8125
# Batch number: 3693/3750, Training: Loss: 0.1907, Accuracy: 0.9375
# Batch number: 3694/3750, Training: Loss: 0.1660, Accuracy: 0.9375
# Batch number: 3695/3750, Training: Loss: 0.5224, Accuracy: 0.8750
# Batch number: 3696/3750, Training: Loss: 0.1513, Accuracy: 1.0000
# Batch number: 3697/3750, Training: Loss: 0.1375, Accuracy: 1.0000
# Batch number: 3698/3750, Training: Loss: 0.1411, Accuracy: 0.9375
# Batch number: 3699/3750, Training: Loss: 0.3783, Accuracy: 0.8750
# Batch number: 3700/3750, Training: Loss: 0.2597, Accuracy: 0.9375
# Batch number: 3701/3750, Training: Loss: 0.1985, Accuracy: 0.9375
# Batch number: 3702/3750, Training: Loss: 0.1933, Accuracy: 0.9375
# Batch number: 3703/3750, Training: Loss: 0.9751, Accuracy: 0.8125
# Batch number: 3704/3750, Training: Loss: 0.5224, Accuracy: 0.8125
# Batch number: 3705/3750, Training: Loss: 0.0903, Accuracy: 1.0000
# Batch number: 3706/3750, Training: Loss: 0.4481, Accuracy: 0.8750
# Batch number: 3707/3750, Training: Loss: 0.2216, Accuracy: 0.8750
# Batch number: 3708/3750, Training: Loss: 0.3642, Accuracy: 0.8750
# Batch number: 3709/3750, Training: Loss: 0.4574, Accuracy: 0.9375
# Batch number: 3710/3750, Training: Loss: 0.0291, Accuracy: 1.0000
# Batch number: 3711/3750, Training: Loss: 0.6202, Accuracy: 0.8750
# Batch number: 3712/3750, Training: Loss: 0.0862, Accuracy: 0.9375
# Batch number: 3713/3750, Training: Loss: 0.3342, Accuracy: 0.8750
# Batch number: 3714/3750, Training: Loss: 0.0401, Accuracy: 1.0000
# Batch number: 3715/3750, Training: Loss: 0.3077, Accuracy: 0.8750
# Batch number: 3716/3750, Training: Loss: 0.5825, Accuracy: 0.8750
# Batch number: 3717/3750, Training: Loss: 0.2217, Accuracy: 0.8750
# Batch number: 3718/3750, Training: Loss: 0.1283, Accuracy: 0.9375
# Batch number: 3719/3750, Training: Loss: 0.3995, Accuracy: 0.8125
# Batch number: 3720/3750, Training: Loss: 0.2756, Accuracy: 0.8750
# Batch number: 3721/3750, Training: Loss: 0.3190, Accuracy: 0.9375
# Batch number: 3722/3750, Training: Loss: 0.3131, Accuracy: 0.9375
# Batch number: 3723/3750, Training: Loss: 0.1341, Accuracy: 0.9375
# Batch number: 3724/3750, Training: Loss: 0.0462, Accuracy: 1.0000
# Batch number: 3725/3750, Training: Loss: 0.3625, Accuracy: 0.8750
# Batch number: 3726/3750, Training: Loss: 0.2485, Accuracy: 0.8750
# Batch number: 3727/3750, Training: Loss: 0.0600, Accuracy: 1.0000
# Batch number: 3728/3750, Training: Loss: 0.1049, Accuracy: 1.0000
# Batch number: 3729/3750, Training: Loss: 0.1242, Accuracy: 1.0000
# Batch number: 3730/3750, Training: Loss: 0.1876, Accuracy: 0.9375
# Batch number: 3731/3750, Training: Loss: 0.0956, Accuracy: 0.9375
# Batch number: 3732/3750, Training: Loss: 0.1503, Accuracy: 0.9375
# Batch number: 3733/3750, Training: Loss: 0.2077, Accuracy: 0.9375
# Batch number: 3734/3750, Training: Loss: 0.2065, Accuracy: 0.9375
# Batch number: 3735/3750, Training: Loss: 0.2650, Accuracy: 0.8750
# Batch number: 3736/3750, Training: Loss: 0.3021, Accuracy: 0.8750
# Batch number: 3737/3750, Training: Loss: 0.5077, Accuracy: 0.7500
# Batch number: 3738/3750, Training: Loss: 0.0558, Accuracy: 1.0000
# Batch number: 3739/3750, Training: Loss: 0.4759, Accuracy: 0.8750
# Batch number: 3740/3750, Training: Loss: 0.2563, Accuracy: 0.8750
# Batch number: 3741/3750, Training: Loss: 0.7455, Accuracy: 0.8125
# Batch number: 3742/3750, Training: Loss: 0.2583, Accuracy: 0.9375
# Batch number: 3743/3750, Training: Loss: 0.2362, Accuracy: 0.9375
# Batch number: 3744/3750, Training: Loss: 0.2344, Accuracy: 0.9375
# Batch number: 3745/3750, Training: Loss: 0.2614, Accuracy: 0.8750
# Batch number: 3746/3750, Training: Loss: 0.1575, Accuracy: 0.9375
# Batch number: 3747/3750, Training: Loss: 0.2061, Accuracy: 0.8750
# Batch number: 3748/3750, Training: Loss: 0.1926, Accuracy: 0.9375
# Batch number: 3749/3750, Training: Loss: 0.1005, Accuracy: 1.0000

# %%
# Vamos colocar o modelo em modo de avaliação.
vgg_16_model.eval()

# Criar o dataloader para iterar nos dados.
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False, num_workers=1)

# Vamos medir a performance do modelo sem o refinamento.
correct = 0
for batch_idx, (data, target) in enumerate(test_loader):
    # Coloando os dados nos dispositivos.
    data = data.to(device)
    target = target.to(device)

    # Processando os dados.
    output = vgg_16_model(data)
    if target == torch.argmax(torch.softmax(output, dim=1)):
        correct = correct + 1

# Calcula acurácia.
acc = correct/len(test_data)
print(f"Acurácia com modelo com refinamento: {acc * 100}%")
# Out:
# Acurácia com modelo com refinamento: 95.93%

# %% [markdown]
# E com isso terminamos a prática de hoje.

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas práticas vamos trasbalhar com problemas clássicos de Visão Computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://pytorch.org/
# - https://docs.pytorch.org/vision/main/models.html
# - https://docs.pytorch.org/vision/0.8/datasets.html
# - https://opencv.org/
# - https://learnopencv.com/blogs/
# - https://pyimagesearch.com/

# %% [markdown]
# ## Atividades Complementares (Opicional)

# %% [markdown]
# - [ ] Altere os hiperparâmetros, como número de epocas, tamanho do batch e learning rate do otimizador.
# - [ ] Tente utilizar outro modelo pré-treinado da mesma forma que utilizamos o modelo VGG 16.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Pré-processamento

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(256),
    torchvision.transforms.CenterCrop(224),
    torchvision.transforms.Grayscale(num_output_channels=3),
    torchvision.transforms.ToTensor()
])

# %% [markdown]
# Carregar dados

# %%
train_data = torchvision.datasets.MNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

test_data = torchvision.datasets.MNIST(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

print("Treino:", len(train_data))
print("Teste:", len(test_data))
# Out:
# Treino: 60000
# Teste: 10000

# %% [markdown]
# Visualizar imagens

# %%
indexes = [
    np.random.randint(0, len(train_data)),
    np.random.randint(0, len(train_data))
]

fig, axes = plt.subplots(1, 2, figsize=(8, 4))

for i in range(2):
    image, label = train_data[indexes[i]]
    axes[i].imshow(image.permute(1, 2, 0))
    axes[i].set_title(f"Label: {label}")
    axes[i].axis("off")

plt.show()

# %% [markdown]
# Carregar VGG16

# %%
vgg_16_model = torchvision.models.vgg16(
    weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1
)

num_classes = 10

in_features = vgg_16_model.classifier[6].in_features

vgg_16_model.classifier[6] = torch.nn.Linear(
    in_features,
    num_classes
)

# %% [markdown]
# Congelar convoluções

# %%
for param in vgg_16_model.features.parameters():
    param.requires_grad = False

# %% [markdown]
# Hiperparâmetros

# %%
epochs = 5
batch_size = 64
learning_rate = 0.001

device = "cuda" if torch.cuda.is_available() else "cpu"

vgg_16_model = vgg_16_model.to(device)

print("Dispositivo:", device)
# Out:
# Dispositivo: cuda

# %% [markdown]
# DataLoaders

# %%
train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2
)

test_loader = torch.utils.data.DataLoader(
    test_data,
    batch_size=batch_size,
    shuffle=False,
    num_workers=2
)

# %% [markdown]
# Otimizador e Loss

# %%
optimizer = torch.optim.SGD(
    filter(lambda p: p.requires_grad,
           vgg_16_model.parameters()),
    lr=learning_rate,
    momentum=0.9
)

criterion = torch.nn.CrossEntropyLoss()

# %% [markdown]
# Treinamento

# %%
scaler = torch.amp.GradScaler("cuda")

# %%
for epoch in range(epochs):

    vgg_16_model.train()

    running_loss = 0.0
    running_correct = 0
    total_samples = 0

    for inputs, labels in train_loader:

        inputs = inputs.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        with torch.amp.autocast("cuda"):
            outputs = vgg_16_model(inputs)
            loss = criterion(outputs, labels)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        batch_size = labels.size(0)

        running_loss += loss.item() * batch_size
        running_correct += (outputs.argmax(1) == labels).sum().item()
        total_samples += batch_size

    print(
        f"Epoch {epoch+1}/{epochs} | "
        f"Loss: {running_loss/total_samples:.4f} | "
        f"Acc: {running_correct/total_samples:.4f}"
    )
# Out:
# Epoch 1/5 | Loss: 0.0868 | Acc: 0.9728
# Epoch 2/5 | Loss: 0.0588 | Acc: 0.9820
# Epoch 3/5 | Loss: 0.0470 | Acc: 0.9856
# Epoch 4/5 | Loss: 0.0386 | Acc: 0.9877
# Epoch 5/5 | Loss: 0.0331 | Acc: 0.9897

# %% [markdown]
# Avaliação

# %%
vgg_16_model.eval()

correct = 0

with torch.no_grad():

    for data, target in test_loader:

        data = data.to(device)
        target = target.to(device)

        output = vgg_16_model(data)

        pred = output.argmax(dim=1)

        correct += pred.eq(target).sum().item()

acc = correct / len(test_data)

print(f"Acurácia final: {acc*100:.2f}%")
# Out:
# Acurácia final: 99.09%

# %% [markdown]
# Teste visual

# %%
idx = np.random.randint(0, len(test_data))

image, label = test_data[idx]

with torch.no_grad():
    prediction = vgg_16_model(
        image.unsqueeze(0).to(device)
    ).argmax(1).item()

plt.imshow(image.permute(1, 2, 0))
plt.title(
    f"Real: {label} | Predito: {prediction}"
)
plt.axis("off")
plt.show()

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %% [markdown]
# [ ] Tente utilizar outro modelo pré-treinado da mesma forma que utilizamos o modelo VGG 16.

# %% [markdown]
# Usando EfficientNet-B0

# %%
from torch import nn
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights

# %%
weights = EfficientNet_B0_Weights.DEFAULT
model = efficientnet_b0(weights=weights)

for param in model.parameters():
    param.requires_grad = False

num_classes = len(train_data.classes)

model.classifier[1] = nn.Linear(
    model.classifier[1].in_features,
    num_classes
)

model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.classifier.parameters(),
    lr=1e-3
)

# %%
model.eval()

correct = 0
total = 0

with torch.inference_mode(): 

    for data, target in test_loader:

        data = data.to(device, non_blocking=True)
        target = target.to(device, non_blocking=True)

        output = model(data)

        pred = output.argmax(dim=1)

        correct += (pred == target).sum().item()
        total += target.size(0)

acc = correct / total

print(f"Acurácia final (EfficientNet-B0): {acc * 100:.2f}%")
# Out:
# Acurácia final (EfficientNet-B0): 13.27%

# %%
idx = np.random.randint(0, len(test_data))

image, label = test_data[idx]

with torch.no_grad():
    prediction = vgg_16_model(
        image.unsqueeze(0).to(device)
    ).argmax(1).item()

plt.imshow(image.permute(1, 2, 0))
plt.title(
    f"Real: {label} | Predito: {prediction}"
)
plt.axis("off")
plt.show()
