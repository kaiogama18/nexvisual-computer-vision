# %% [markdown]
# # M5A3 - Identificação de Elementos Visuais em UI de Aplicativos

# %% [markdown]
# Na prática de hoje vamos refinar um modelo para a tarefa de indetificação de elementos visuais.
#
# Esse notebook está estruturado da seguinte forma.
#
# - Introdução
# - Carregar Base de Dados
# - Refinar Modelo
# - Validar o modelo
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Introdução

# %% [markdown]
# Instalação para os que ainda não possuem a biblioteca instalada.

# %%
# !pip install torch torchvision datasets tqdm ipywidgets
# Out:
# Requirement already satisfied: torch in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (2.11.0+cu128)
# Requirement already satisfied: torchvision in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (0.26.0+cu128)
# Requirement already satisfied: datasets in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (5.0.0)
# Requirement already satisfied: tqdm in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (4.68.3)
# Requirement already satisfied: ipywidgets in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (8.1.8)
# Requirement already satisfied: filelock in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torch) (2026.4.0)
# Requirement already satisfied: numpy in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torchvision) (2.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (2.34.2)
# Requirement already satisfied: httpx<1.0.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (3.7.1)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (1.21.0)
# Requirement already satisfied: packaging in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: anyio in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from httpx<1.0.0->datasets) (4.14.1)
# Requirement already satisfied: certifi in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from httpx<1.0.0->datasets) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from httpx<1.0.0->datasets) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.25.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: colorama in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipywidgets) (9.14.1)
# Requirement already satisfied: traitlets>=4.3.1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipywidgets) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: psutil>=7 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\kaiog\Documents\nexvisual-computer-vision\modulos\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# Importar as bibliotecas

# %%
import datasets
import torch
import torchvision
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregar Base de Dados
#
# A primeira tarefa para refinar um modelo é criar a base de dados.
#
# Referência: https://huggingface.co/datasets/mrtoy/mobile-ui-design

# %%
# Baixando dataset.
# Esse dataset possui apenas split de treino.
dataset = datasets.load_dataset("mrtoy/mobile-ui-design", split="train")

# Split dataset.
split_ds = dataset.train_test_split(test_size=0.1, seed=42)

# Pegar splits de dados.
train_dataset = split_ds["train"]
test_dataset = split_ds["test"]

# Transformações dos dados.
def transforms(examples):
    #Transformações das imagens.
    transforms = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(), # Transforma em tensor.
        torchvision.transforms.Resize((640, 480)), # Faz resize das imagens.
    ])

    images = [transforms(image) for image in examples["image"]] # Aplica nas imagens

    # Intera nos dados de bounding boxes e classes.
    targets = []
    for objs in examples["objects"]:
        len_objs = len(objs["category"])
        for i in range(len_objs):
            boxes = torch.tensor(objs["bbox"][i], dtype=torch.float32)
            boxes = torchvision.ops.box_convert(boxes, in_fmt="xywh", out_fmt="xyxy").unsqueeze(0) # Converte o formato da bbox.          

            label_map = {"rectangle": 0, "text": 1, "group": 2, "image": 3}
            labels = torch.tensor(label_map[objs["category"][i]], dtype=torch.int64).unsqueeze(0) # Transforma categoria em int.
            
            target = {"boxes": boxes, "labels": labels}
            targets.append(target)
    
    # Retorna dicionário compatível com dataloader.
    return {"image": images, "target": targets}

train_dataset =  train_dataset.with_transform(transforms)
test_dataset = test_dataset.with_transform(transforms)

def collate_fn(batch):
    # Organiza o retorno do dataloader.
    images = [item["image"] for item in batch]
    targets = [item["target"] for item in batch]
    return images, targets

# Criando dataloaders.
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)
# Out:
# README.md:   0%|          | 0.00/3.30k [00:00<?, ?B/s]
# data/train-00000-of-00003-b9a78b2072fee3(…):   0%|          | 0.00/392M [00:00<?, ?B/s]
# data/train-00001-of-00003-d1f3cb3379d494(…):   0%|          | 0.00/387M [00:00<?, ?B/s]

# %%
# Baixando dataset.
# Esse dataset possui apenas split de treino.
dataset = datasets.load_dataset("mrtoy/mobile-ui-design", split="train")
# Out:
# data/train-00002-of-00003-ae5f3fe59ef581(…):   0%|          | 0.00/382M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7846 [00:00<?, ? examples/s]

# %%
# Split dataset.
split_ds = dataset.train_test_split(test_size=0.1, seed=42)

# Pegar splits de dados.
train_dataset = split_ds["train"]
test_dataset = split_ds["test"]

# %%
img_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((640, 480)),
    torchvision.transforms.ToTensor(),
])

# %%
def transforms(examples):
    images = [img_transform(image) for image in examples["image"]]

    targets = []
    for objs in examples["objects"]:
        boxes = torch.tensor(objs["bbox"], dtype=torch.float32)
        boxes = torchvision.ops.box_convert(
            boxes,
            in_fmt="xywh",
            out_fmt="xyxy"
        )

        label_map = {"rectangle": 0, "text": 1, "group": 2, "image": 3}
        labels = torch.tensor(
            [label_map[c] for c in objs["category"]],
            dtype=torch.int64
        )

        targets.append({
            "boxes": boxes,
            "labels": labels
        })

    return {"image": images, "target": targets}

# %%
def collate_fn(batch):
    # Organiza o retorno do dataloader.
    images = [item["image"] for item in batch]
    targets = [item["target"] for item in batch]
    return images, targets

# %%
# Criando dataloaders.

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=4,
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=4,    
    pin_memory=True,
)

# %%
# Transformações dos dados.
def transforms(examples):
    #Transformações das imagens.
    transforms = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(), # Transforma em tensor.
        torchvision.transforms.Resize((640, 480)), # Faz resize das imagens.
    ])

    images = [transforms(image) for image in examples["image"]] # Aplica nas imagens

    # Intera nos dados de bounding boxes e classes.
    targets = []
    for objs in examples["objects"]:
        len_objs = len(objs["category"])
        for i in range(len_objs):
            boxes = torch.tensor(objs["bbox"][i], dtype=torch.float32)
            boxes = torchvision.ops.box_convert(boxes, in_fmt="xywh", out_fmt="xyxy").unsqueeze(0) # Converte o formato da bbox.          

            label_map = {"rectangle": 0, "text": 1, "group": 2, "image": 3}
            labels = torch.tensor(label_map[objs["category"][i]], dtype=torch.int64).unsqueeze(0) # Transforma categoria em int.
            
            target = {"boxes": boxes, "labels": labels}
            targets.append(target)
    
    # Retorna dicionário compatível com dataloader.
    return {"image": images, "target": targets}

train_dataset =  train_dataset.with_transform(transforms)
test_dataset = test_dataset.with_transform(transforms)

# %%
train_dataset =  train_dataset.with_transform(transforms)
test_dataset = test_dataset.with_transform(transforms)

def collate_fn(batch):
    # Organiza o retorno do dataloader.
    images = [item["image"] for item in batch]
    targets = [item["target"] for item in batch]
    return images, targets

# Criando dataloaders.
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# %% [markdown]
# ## Refinar Modelo
#
# Na prática de hoje iremos refinar o modelo **Faster R-CNN** disponível no torchvision.

# %%
# Definindo dispositivo.
device = "cuda" if torch.cuda.is_available() else "cpu"

# Carregando modelo.
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")

num_classes = 5 # número de classes no nosso dataset + 1 para a classe background.
in_features = model.roi_heads.box_predictor.cls_score.in_features # número de features da última camada.
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes) # substitui a última camada do modelo.

model.to(device) # Colocando modelo no dispositivo.

# Definindo o otimizador.
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0001)

# Treinamento do modelo
model.train()
epochs = 1 # Alterar para treinar mais epocas.
for epoch in range(epochs):
    iteration = 0
    for images, targets in tqdm(train_loader):
        # Muda o dispostivo de processamento dos dados.
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        # Modelo retorna um dicionário de losses durante o treinamento.
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        
        if iteration % 100 == 0:
            print(f"Total loss: {losses.item()}")
        iteration += 1
# Out:
#   0%|          | 0/1766 [00:00<?, ?it/s]
# Total loss: 2.2855842113494873
# Total loss: 0.14183054864406586
# Total loss: 0.14480555057525635
# Total loss: 0.15092027187347412
# Total loss: 0.12135270982980728
# Total loss: 0.19595776498317719
# Total loss: 0.20443083345890045
# Total loss: 0.20444604754447937
# Total loss: 0.17105744779109955
# Total loss: 0.17483609914779663
# Total loss: 1.0204107761383057
# Total loss: 0.1112850159406662
# Total loss: 0.15739208459854126
# Total loss: 4.027468681335449
# Total loss: 47.772247314453125
# Total loss: 0.19093281030654907
# Total loss: 0.19793039560317993
# Total loss: 0.10952962934970856

# %% [markdown]
# ## Validar Modelo
#
# Agora vamos testar o nosso modelo.

# %%
# Tamanho do dataset de teste.
len_test_data = len(test_dataset)

# Sortear amostra do dataset de teste.
idx = torch.randint(len_test_data, (1,))

# Modelo em modo de avaliação
model.eval()
with torch.no_grad():
    x = test_dataset[idx]["image"][0]
    # convert RGBA -> RGB and move to device
    x = x[:3, ...].to(device)
    predictions = model([x, ])
    pred = predictions[0]


inverse_label_map = {0:"rectangle", 1:"text", 2:"group", 3:"image"}
image = x
image = (255.0 * (image - image.min()) / (image.max() - image.min())).to(torch.uint8)
image = image[:3, ...]
pred_labels = [f"{inverse_label_map[int(label.cpu())]}: {score:.3f}" for label, score in zip(pred["labels"], pred["scores"])]
pred_boxes = pred["boxes"].long()
output_image = torchvision.utils.draw_bounding_boxes(image, pred_boxes, pred_labels, colors="red")

plt.figure(figsize=(12, 12))
plt.imshow(output_image.permute(1, 2, 0).cpu())

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas práticas vamos continuar trabalhando com problemas reais que envolvem Visão Computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://docs.pytorch.org/vision/master/models/faster_rcnn.html
# - https://huggingface.co/datasets/mrtoy/mobile-ui-design
# - https://huggingface.co/datasets
# - https://pytorch.org/
# - https://docs.pytorch.org/vision/main/models.html
# - https://opencv.org/
# - https://learnopencv.com/blogs/
# - https://pyimagesearch.com/

# %% [markdown]
# ## Atividades Complementares (Opcional)

# %% [markdown]
# - [ ] Tente treinar por mais tempo, os resultados melhoram?
# - [ ] Tente alterar alguns hiperparâmetros de treinamento, batch e resolução da imagens, learning rate e veja como isso altera os resultados.

# %%
img_transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((800, 600)),
    torchvision.transforms.ToTensor(),
])

# %%
train_dataset =  train_dataset.with_transform(transforms)
test_dataset = test_dataset.with_transform(transforms)

def collate_fn(batch):
    # Organiza o retorno do dataloader.
    images = [item["image"] for item in batch]
    targets = [item["target"] for item in batch]
    return images, targets

# Criando dataloaders.
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=2, shuffle=True, collate_fn=collate_fn)

# %%
# Definindo dispositivo.
device = "cuda" if torch.cuda.is_available() else "cpu"

# Carregando modelo.
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")

num_classes = 5 # número de classes no nosso dataset + 1 para a classe background.
in_features = model.roi_heads.box_predictor.cls_score.in_features # número de features da última camada.
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes) # substitui a última camada do modelo.

model.to(device) # Colocando modelo no dispositivo.

# Definindo o otimizador.
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=0.0001)

# Treinamento do modelo
model.train()
epochs = 1 # Alterar para treinar mais epocas.
for epoch in range(epochs):
    iteration = 0
    for images, targets in tqdm(train_loader):
        # Muda o dispostivo de processamento dos dados.
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        # Modelo retorna um dicionário de losses durante o treinamento.
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        
        if iteration % 100 == 0:
            print(f"Total loss: {losses.item()}")
        iteration += 1
# Out:
#   0%|          | 0/3531 [00:00<?, ?it/s]
# Total loss: 1.8209208250045776
# Total loss: 0.10481926798820496
# Total loss: 0.1662071794271469
# Total loss: 80.88011932373047
# Total loss: 0.11810307204723358
# Total loss: 0.0991268903017044
# Total loss: 0.13573980331420898
# Total loss: 0.133562833070755
# Total loss: 0.2450282871723175
# Total loss: 0.21410469710826874
# Total loss: 0.15030792355537415
# Total loss: 0.11400943994522095
# Total loss: 0.10729461908340454
# Total loss: 0.18225935101509094
# Total loss: 0.14792917668819427
# Total loss: 0.16640299558639526
# Total loss: 0.09286177903413773
# Total loss: 0.11554399132728577
# Total loss: 0.15812614560127258
# Total loss: 0.19859571754932404
# Total loss: 0.22680242359638214
# Total loss: 0.1825098842382431
# Total loss: 0.1180955171585083
# Total loss: 0.16364742815494537
# Total loss: 0.21208637952804565
# Total loss: 0.05313537269830704
# Total loss: 0.15617777407169342
# Total loss: 0.07460182160139084
# Total loss: 0.15785309672355652
# Total loss: 0.11003885418176651
# Total loss: 1.3124773502349854
# Total loss: 0.3894652724266052
# Total loss: 0.21024228632450104
# Total loss: 0.10763943195343018
# Total loss: 50.67397689819336
# Total loss: 0.07441757619380951
