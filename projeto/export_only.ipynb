# %% [markdown]
# # Somente para parte de Exportação
#
# Exporta para uso em Android (TFLite).

# %%
from ultralytics import YOLO

# %% [markdown]
# Carregando o modelo com YOLO:

# %%
model = YOLO("runs/detect/train-6/weights/best.pt")

# %%
model.export(
    format='tflite',
    int8=True  # ⚡ melhor performance para mobile
)
# Out:
# Ultralytics 8.4.67  Python-3.11.9 torch-2.11.0+cu128 CPU (12th Gen Intel Core i7-12700H)
# WARNING INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'runs\detect\train-6\weights\best.pt' with input shape (1, 3, 416, 416) BCHW and output shape(s) (1, 5, 3549) (5.9 MB)
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=coco8.yaml'
# val: Fast image access  (ping: 0.10.1 ms, read: 157.282.7 MB/s, size: 54.0 KB)
# val: Scanning C:\Users\kaiog\Documents\11 - Git\01 - GitHub\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4  0.0s
# WARNING TensorFlow SavedModel: >300 images recommended for INT8 calibration, found 4 images.
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.94...
# ...

# %% [markdown]
# ## 📱 Output
#
# Depois do export você terá:
# - best.tflite
# - labels
#
# Pronto para usar no Android (Kotlin + CameraX).
